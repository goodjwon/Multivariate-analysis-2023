# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

co2 = pd.read_csv("./mva/co2.csv")
co2.head(2)
# Out:
#    Unnamed: 0       x
# 0           1  315.42
# 1           2  316.31

# %%
co2.columns=["seq", "x"]
co2.head(2)
# Out:
#    seq       x
# 0    1  315.42
# 1    2  316.31

# %%
plt.plot(co2.seq, co2.x)

# %%
x = np.arange(0, 20, 0.1)
y = np.exp(-x/10)*np.cos(2*x)
plt.plot(x,y)

# %%
us = pd.read_csv('./mva/USairpollution.csv')
us.head()
us['SO2'] = us['SO2']*5

plt.scatter('temp', 'wind', s='SO2', alpha=0.9, data=us)
# plt.xlabel = ('temp')
# plt.ylabel = ('wind')
plt.title("Bubble plot")
# Out:
# Text(0.5, 1.0, 'Bubble plot')
